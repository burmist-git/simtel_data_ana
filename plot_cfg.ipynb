# %%
import pandas as pd
import numpy as np

# %%
atm_data='/home/burmist/home2/work/CTA/corsika7.7_simtelarray_2020-06-28_patch/sim_telarray/cfg/common/atm_trans_2158_1_3_2_0_0_0.1_0.1.dat'

# %%
df=pd.read_csv(atm_data,comment='#',header=None,delim_whitespace=True)

# %%
# H2= 2.158, H1=    2.208     2.258     2.358     2.458     2.658     2.858     3.158     3.658     4.158     4.500     5.000     5.500     6.000     7.000     8.000     9.000    10.000    11.000    12.000    13.000    14.000    15.000    16.000    18.000    20.000    22.000    24.000    26.000    28.000    30.000    32.500    35.000    37.500    40.000    45.000    50.000    60.000    70.000    80.000    100.000

# %%
np.exp(-df[[1,2,3,4,5,10,20,30,40]]).plot()
# Out:
# <Axes: >
